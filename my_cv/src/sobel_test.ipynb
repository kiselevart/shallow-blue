# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import image as im

impath = "/Users/kisel/projects/shallow-blue/my_cv/im1.jpeg"
img = im.imread(impath)
plt.imshow(img)

# %%
from PIL import Image
img = Image.open(impath)
pixels = list(img.getdata())

grayscale = []
for pixel in pixels:
    grayscale.append(pixel[0] * 0.2989 + pixel[1] * 0.5870 + pixel[2] * 0.1140)

graynp = np.array(grayscale).reshape(img.size)
gray = Image.fromarray(graynp)
gray.show()

# %%
from matplotlib.pyplot import imshow
def sobel_filter(grayscale_img):
    def cross_corr(img_data, kernel):
        rows, cols, num_alphas = img_data.shape
        for i in range(1, rows-1):
            for j in range(1, cols-1):
                curr_mat = img_data[(i-1):(i+2), (j-1):(j+2)]

    data = np.array(grayscale_img.getdata()).reshape(400, 400, 3)
    rows, cols, num_alphas = data.shape
    row_pad = np.zeros((1, cols, num_alphas))
    col_pad = np.zeros((rows+2, 1, num_alphas))

    row_padded = np.vstack((row_pad, data, row_pad))
    padded = np.hstack((col_pad, row_padded, col_pad)).astype(int)

    G_x = np.array([
            [-1, 0, 1],
            [-2, 0, 2],
            [-1, 0, 1],
    ])
    G_y = np.array([
            [-1, -2, -1],
            [0, 0, 0],
            [1, 2, 1],
    ])

    cross_corr(padded, G_x)

    return padded

pad = sobel_filter(img)
plt.imshow(pad)
# Out:
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# (3, 3, 3)
# ...
